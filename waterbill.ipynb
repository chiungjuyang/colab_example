# %% [markdown]
# 抄表計費水價和各口徑基本費 https://www.water.gov.tw/ch/Subject/Detail/1288?nodeId=813
#
# 水費試算 https://www.water.gov.tw/ch/EQuery/WaterFeeTrail?nodeId=754
#
# 一般用戶用水兩個月的水費小計(用水費+基本費)

# %%
n=float(input("請輸入用水度數:"))
if n<=20 : s=7.35*n
elif n<=60 : s=9.45*n-21
elif n<=100 : s=11.55*n-84
else : s=12.075*n-110.25
	

m=int(input("請輸入水表口徑mm:(13、20、25、40、50、75、100、150、200、250、300、350、400以上)"))
if m==13 : k=35.7
elif m==20 : k=71.4
elif m==25 : k=132.3
elif m==40 : k=392.7
elif m==50 : k=714
elif m==75 : k=1927.8
elif m==100 : k=3819.9
elif m==150 : k=10602.9
elif m==200 : k=21063
elif m==250 : k=37199.4
elif m==300 : k=58369.5
elif m==350 : k=83252.4
else : k=116239.2
		
print("用水費%.2f元" %s)  
print("基本費%.2f元" %k)
print("水費項目小計金額：%.0f元" %(k+s))
# Out:
# 請輸入用水度數:16
# 請輸入水表口徑mm:(13、20、25、40、50、75、100、150、200、250、300、350、400以上)13
# 用水費117.60元
# 基本費35.70元
# 水費項目小計金額：153元

# %% [markdown]
# 每月小計

# %%
import sys  
s=k=0

n=float(input("請輸入用水度數:"))
if(n>=0 and n<=10):  #用水費
	s=7.35*n
elif(n>10 and n<=30):
	s=9.45*n-21
elif(n>30 and n<=50):
	s=11.55*n-84
elif(n>51):
	s=12.075*n-110.25
else:
	print("用水度數輸入錯誤")
	sys.exit()
	
print("水表口徑(13、20、25、40、50、75、100、150、200、250、300、350、400以上)")
m=int(input("請輸入水表口徑(單位:毫米):"))
if(m>=400):  #基本費
	k=58119.6
else:
	if(m==13):
		k=17.85
	elif(m==20):
		k=35.7
	elif(m==25):
		k=66.15
	elif(m==40):
		k=169.35
	elif(m==50):
		k=357
	elif(m==75):
		k=963.9
	elif(m==100):
		k=1909.95
	elif(m==150):
		k=5301.45
	elif(m==200):
		k=10531.5
	elif(m==250):
		k=18599.7
	elif(m==300):
		k=29184.75
	elif(m==350):	
		k=41626.2
	else:
		print("水表口徑輸入錯誤")
		sys.exit()
		
r=(s+k)/1.05*0.05   #營業稅
print("您的基本費%.0f元、用水費%.0f元、營業稅%.0f元" %(k,s,r))
total=k+s+r
print("總計：%.0f元" %(total))
# Out:
# 請輸入用水度數:8
# 水表口徑(13、20、25、40、50、75、100、150、200、250、300、350、400以上)
# 請輸入水表口徑(單位:毫米):13
# 您的基本費18元、用水費59元、營業稅4元
# 總計：80元
